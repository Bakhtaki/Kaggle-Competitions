# %%
# %%time
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tabular-playground-series-jul-2022/sample_submission.csv
# /kaggle/input/tabular-playground-series-jul-2022/data.csv
# CPU times: user 294 µs, sys: 0 ns, total: 294 µs
# Wall time: 688 µs

# %%
# %%time
# Imports Modules 
import math
import os
import sys
import random
import gc
import os
import datetime
import time
import lightgbm as lgb
import optuna


import plotly as py
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import plotly.express as px
warnings.filterwarnings("ignore")
# %matplotlib inline

import umap.plot
from umap import UMAP


from statistics import mean
from plotly.offline import init_notebook_mode


# scipy
from scipy.stats import shapiro , stats, probplot,pearsonr,chi2, poisson

# Sklearn
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import StratifiedKFold ,train_test_split, TimeSeriesSplit 
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
from sklearn.naive_bayes import GaussianNB
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.ensemble import RandomForestClassifier
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# CPU times: user 19.9 s, sys: 1.73 s, total: 21.6 s
# Wall time: 29.5 s

# %% [markdown]
# # Import Data

# %%
# %%time
data_df = pd.read_csv('/kaggle/input/tabular-playground-series-jul-2022/data.csv')
data_df.head()
# Out:
# CPU times: user 537 ms, sys: 68 ms, total: 605 ms
# Wall time: 955 ms
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_19      f_20      f_21      f_22      f_23  \
# 0     2    13  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1     2     3  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2     5    11  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3     6     2  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4     8     7  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
#        f_24      f_25      f_26      f_27      f_28
# 0 -0.884274  1.137896  1.309073  1.463002  0.813527
# 1  1.759412 -0.275422 -0.852168  0.562457 -2.680541
# 2 -2.168635 -0.974989  1.335763 -1.110655 -3.630723
# 3  1.440490 -1.900191 -0.630771 -0.050641  0.238333
# 4  1.473930 -1.044684  1.602686 -0.405263 -1.987263
#
# [5 rows x 30 columns]

# %%
data_id = data_df['id']
data_df = data_df.drop('id',axis=1)
data_df.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  f_07  \
# 0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560     2
# 1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651     2
# 2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301     5
# 3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850     6
# 4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898     8
#
#    f_08  f_09  ...      f_19      f_20      f_21      f_22      f_23  \
# 0    13    14  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1     3     6  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2    11     5  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3     2    13  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4     7     5  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
#        f_24      f_25      f_26      f_27      f_28
# 0 -0.884274  1.137896  1.309073  1.463002  0.813527
# 1  1.759412 -0.275422 -0.852168  0.562457 -2.680541
# 2 -2.168635 -0.974989  1.335763 -1.110655 -3.630723
# 3  1.440490 -1.900191 -0.630771 -0.050641  0.238333
# 4  1.473930 -1.044684  1.602686 -0.405263 -1.987263
#
# [5 rows x 29 columns]

# %% [markdown]
# # EDA

# %%
print("data rows:",data_df.shape[0])
print("data rows:",data_df.shape[1])
print("Null Values: ",data_df.isnull().sum().sum())
# Out:
# data rows: 98000
# data rows: 29
# Null Values:  0

# %%
data_df.describe().T.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_5301f_row0_col0, #T_5301f_row0_col2, #T_5301f_row0_col6, #T_5301f_row1_col0, #T_5301f_row1_col2, #T_5301f_row1_col6, #T_5301f_row2_col0, #T_5301f_row2_col2, #T_5301f_row2_col6, #T_5301f_row3_col0, #T_5301f_row3_col2, #T_5301f_row3_col6, #T_5301f_row4_col0, #T_5301f_row4_col2, #T_5301f_row4_col6, #T_5301f_row4_col7, #T_5301f_row5_col0, #T_5301f_row5_col2, #T_5301f_row5_col6, #T_5301f_row6_col0, #T_5301f_row6_col2, #T_5301f_row6_col6, #T_5301f_row6_col7, #T_5301f_row7_col0, #T_5301f_row8_col0, #T_5301f_row9_col0, #T_5301f_row10_col0, #T_5301f_row11_col0, #T_5301f_row12_col0, #T_5301f_row13_col0, #T_5301f_row14_col0, #T_5301f_row14_col2, #T_5301f_row14_col6, #T_5301f_row15_col0, #T_5301f_row15_col2, #T_5301f_row15_col6, #T_5301f_row16_col0, #T_5301f_row16_col2, #T_5301f_row16_col6, #T_5301f_row17_col0, #T_5301f_row17_col2, #T_5301f_row17_col6, #T_5301f_row18_col0, #T_5301f_row18_col2, #T_5301f_row18_col6, #T_5301f_row19_col0, #T_5301f_row19_col2, #T_5301f_row19_col6, #T_5301f_row20_col0, #T_5301f_row20_col2, #T_5301f_row20_col6, #T_5301f_row21_col0, #T_5301f_row21_col2, #T_5301f_row21_col6, #T_5301f_row21_col7, #T_5301f_row22_col0, #T_5301f_row23_col0, #T_5301f_row23_col1, #T_5301f_row23_col3, #T_5301f_row24_col0, #T_5301f_row25_col0, #T_5301f_row26_col0, #T_5301f_row27_col0, #T_5301f_row28_col0, #T_5301f_row28_col1, #T_5301f_row28_col4, #T_5301f_row28_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_5301f_row0_col1, #T_5301f_row1_col1, #T_5301f_row14_col1, #T_5301f_row16_col1, #T_5301f_row17_col1, #T_5301f_row20_col1, #T_5301f_row25_col6 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_5301f_row0_col3, #T_5301f_row20_col3 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_5301f_row0_col4, #T_5301f_row1_col4, #T_5301f_row2_col4, #T_5301f_row3_col4, #T_5301f_row5_col4, #T_5301f_row14_col4, #T_5301f_row16_col4, #T_5301f_row17_col4, #T_5301f_row21_col4 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_5301f_row0_col5, #T_5301f_row1_col5, #T_5301f_row2_col5, #T_5301f_row3_col5, #T_5301f_row4_col5, #T_5301f_row5_col5, #T_5301f_row6_col5, #T_5301f_row14_col5, #T_5301f_row15_col5, #T_5301f_row16_col5, #T_5301f_row17_col5, #T_5301f_row18_col5, #T_5301f_row19_col5, #T_5301f_row20_col5, #T_5301f_row21_col5 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_5301f_row0_col7, #T_5301f_row2_col7, #T_5301f_row14_col7, #T_5301f_row19_col7 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_5301f_row1_col3, #T_5301f_row16_col3 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_5301f_row1_col7, #T_5301f_row3_col7, #T_5301f_row20_col7, #T_5301f_row23_col4, #T_5301f_row23_col6, #T_5301f_row28_col6 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_5301f_row2_col1, #T_5301f_row3_col1, #T_5301f_row4_col1, #T_5301f_row5_col1, #T_5301f_row6_col1, #T_5301f_row15_col1, #T_5301f_row18_col1, #T_5301f_row19_col1, #T_5301f_row21_col1, #T_5301f_row22_col5, #T_5301f_row22_col6, #T_5301f_row26_col5, #T_5301f_row27_col6 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_5301f_row2_col3, #T_5301f_row14_col3 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_5301f_row3_col3 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_5301f_row4_col3, #T_5301f_row15_col3 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_5301f_row4_col4, #T_5301f_row6_col4, #T_5301f_row15_col4, #T_5301f_row18_col4, #T_5301f_row19_col4, #T_5301f_row20_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_5301f_row5_col3 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_5301f_row5_col7, #T_5301f_row18_col7, #T_5301f_row26_col6 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_5301f_row6_col3, #T_5301f_row19_col3 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col1 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col2 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col3, #T_5301f_row8_col3, #T_5301f_row9_col1, #T_5301f_row9_col2, #T_5301f_row9_col3, #T_5301f_row9_col6, #T_5301f_row9_col7, #T_5301f_row10_col3, #T_5301f_row10_col4, #T_5301f_row10_col6, #T_5301f_row11_col3, #T_5301f_row11_col4, #T_5301f_row11_col5, #T_5301f_row11_col6, #T_5301f_row12_col3, #T_5301f_row13_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col4, #T_5301f_row13_col4 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col5 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col6 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_5301f_row7_col7, #T_5301f_row12_col2 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col1 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col2 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col4, #T_5301f_row9_col4, #T_5301f_row12_col4 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col5, #T_5301f_row12_col5, #T_5301f_row13_col5 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col6, #T_5301f_row13_col6 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_5301f_row8_col7, #T_5301f_row11_col2, #T_5301f_row13_col7 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_5301f_row9_col5, #T_5301f_row10_col5 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_5301f_row10_col1 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_5301f_row10_col2 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_5301f_row10_col7 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_5301f_row11_col1 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_5301f_row11_col7 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_5301f_row12_col1 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_5301f_row12_col6 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_5301f_row12_col7 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_5301f_row13_col1 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_5301f_row13_col2 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_5301f_row15_col7, #T_5301f_row16_col7, #T_5301f_row17_col7, #T_5301f_row23_col5 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_5301f_row17_col3 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_5301f_row18_col3 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_5301f_row21_col3 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_5301f_row22_col1, #T_5301f_row25_col1, #T_5301f_row25_col4, #T_5301f_row25_col5, #T_5301f_row26_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_5301f_row22_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_5301f_row22_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_5301f_row22_col4 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_5301f_row22_col7, #T_5301f_row27_col2 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_5301f_row23_col2, #T_5301f_row26_col3 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_5301f_row23_col7, #T_5301f_row24_col3, #T_5301f_row24_col5, #T_5301f_row24_col6 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_5301f_row24_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_5301f_row24_col2 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_5301f_row24_col4 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_5301f_row24_col7, #T_5301f_row25_col7, #T_5301f_row26_col2 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_5301f_row25_col2 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_5301f_row25_col3 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_5301f_row26_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_5301f_row26_col7, #T_5301f_row28_col7 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_5301f_row27_col1, #T_5301f_row27_col5 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_5301f_row27_col3, #T_5301f_row28_col2 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_5301f_row27_col4 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_5301f_row27_col7 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_5301f_row28_col3 {
#   background-color: #fed8c7;
#   co

# %% [markdown]
# # Categorial Columns

# %%
# %%time
def get_categorial_colmns(dataframe,Verbose=True):
    """
    Determine Categorial Columns of a DataSet
    Input : DataSet
    Output: List
    """
    catg_cols = []
    for col in dataframe.columns:
        if dataframe.dtypes[col] in ['int8','int16','int32','int64','uint8']:
            catg_cols.append(col)
    
    # --------------------------------------------------------------------
    print(f'There are {len(catg_cols)}: Categorial Columns in DataFrame')
    print(catg_cols,end='')
    print('\n')
    return catg_cols
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.39 µs

# %%
# %%time
categorial_columns = get_categorial_colmns(data_df)
# Out:
# There are 7: Categorial Columns in DataFrame
# ['f_07', 'f_08', 'f_09', 'f_10', 'f_11', 'f_12', 'f_13']
#
# CPU times: user 2.14 ms, sys: 0 ns, total: 2.14 ms
# Wall time: 2.12 ms

# %%
# %%time
def get_continuous_columns(dataframe,verbose=True):
    """
    Use this function to retun countinous  columns of a dataframe
    input : dataframe
    output: list 
    
    """
    continuos_column = []
    for column in dataframe.columns:
        if dataframe.dtypes[column] in ['float16' ,'float32' ,'float64']:
            continuos_column.append(column)
    # -----------------------------------------------------------------------
    print(f'There are {len(continuos_column)}: continous  columns  in Datframe')
    print(continuos_column,end=" ")
    print('\n')
    return continuos_column
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.44 µs

# %%
# %%time
continuous_columns = get_continuous_columns(data_df)
# Out:
# There are 22: continous  columns  in Datframe
# ['f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28']
#
# CPU times: user 2 ms, sys: 3 µs, total: 2 ms
# Wall time: 1.99 ms

# %% [markdown]
# # *Disturbution Of Categorial Columns*

# %%
plt.bar([1,2],[len(categorial_columns),len(continuous_columns)],color="green")
plt.xticks([1,2],["Categorial", 'continuous'])
plt.show()

# %%
# %%time
def dataframe_summary(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Missing_Percent'] = df.isnull().mean().round(2).values
    summary['Uniques'] = df.nunique().values
    return summary
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.3 µs

# %%
# %%time
start_time = datetime.datetime.now()

display(dataframe_summary(data_df))

end_time = datetime.datetime.now()
print('\n')
print('--------------------------------------------------------------------------------')
print(f"Job Started at : {start_time}")
print(f"Job Finished at:{end_time}")
print(f'Total Execution Time is:{end_time - start_time}')
# Out:
# Dataset Shape: (98000, 29)
#     Name   dtypes  Missing  Missing_Percent  Uniques
# 0   f_00  float64        0              0.0    98000
# 1   f_01  float64        0              0.0    98000
# 2   f_02  float64        0              0.0    98000
# 3   f_03  float64        0              0.0    98000
# 4   f_04  float64        0              0.0    98000
# 5   f_05  float64        0              0.0    98000
# 6   f_06  float64        0              0.0    98000
# 7   f_07    int64        0              0.0       32
# 8   f_08    int64        0              0.0       29
# 9   f_09    int64        0              0.0       45
# 10  f_10    int64        0              0.0       37
# 11  f_11    int64        0              0.0       29
# 12  f_12    int64        0              0.0       39
# 13  f_13    int64        0              0.0       30
# 14  f_14  float64        0              0.0    98000
# 15  f_15  float64        0              0.0    98000
# 16  f_16  float64        0              0.0    98000
# 17  f_17  float64        0              0.0    98000
# 18  f_18  float64        0              0.0    98000
# 19  f_19  float64        0              0.0    98000
# 20  f_20  float64        0              0.0    98000
# 21  f_21  float64        0              0.0    98000
# 22  f_22  float64        0              0.0    98000
# 23  f_23  float64        0              0.0    98000
# 24  f_24  float64        0              0.0    98000
# 25  f_25  float64        0              0.0    98000
# 26  f_26  float64        0              0.0    98000
# 27  f_27  float64        0              0.0    98000
# 28  f_28  float64        0              0.0    98000
# --------------------------------------------------------------------------------
# Job Started at : 2022-07-18 07:10:04.643984
# Job Finished at:2022-07-18 07:10:04.765746
# Total Execution Time is:0:00:00.121762
# CPU times: user 122 ms, sys: 25 µs, total: 122 ms
# Wall time: 122 ms

# %% [markdown]
# # *Numerical Columns*

# %%
matrix = np.triu(data_df.corr())
plt.figure(figsize=(30,12))
sns.heatmap(data_df.corr(), annot=True,cmap='YlGnBu', mask=matrix,linecolor='white', cbar=True, linewidths=0.5)
plt.title("Corrlation of Colmns")
sns.set_style({'xtick.bottom':True})
plt.show()

# %%
# %%time
start_time = datetime.datetime.now()

plt.figure(figsize=(24,30))
columns = list(data_df.columns)

for e,c in enumerate(columns,start=1):
    plt.subplot(6,5,e)
    p = sns.histplot(data_df, x=c,kde=True)
    plt.xlabel(c)
    plt.title(f'Feature {c} Distribution)')



end_time = datetime.datetime.now()
print('\n')
print('--------------------------------------------------------------------------------')
print(f"Job Started at : {start_time}")
print(f"Job Finished at:{end_time}")
print(f'Total Execution Time is:{end_time - start_time}')
# Out:
# --------------------------------------------------------------------------------
# Job Started at : 2022-07-18 07:10:07.454041
# Job Finished at:2022-07-18 07:10:24.728484
# Total Execution Time is:0:00:17.274443
# CPU times: user 18.5 s, sys: 2.52 s, total: 21 s
# Wall time: 17.3 s

# %% [markdown]
# # _Distrbution abnormally Detection_

# %%
def abnornmally_indicator(df):
    """Detect Abnormally with Shapiro on Data Frame Columns"""
    abnormally = []

    for col in df.columns:
        # Saprio-wilk Test
        col_shapiro = shapiro(df[col])
        abnormally_indicator = col_shapiro.pvalue 

        if abnormally_indicator > 0.05:
            shapiro_resualt = "Normally Distirbuted"
            abnormally.append((col,abnormally_indicator,shapiro_resualt))
        else:
            shapiro_resualt = "Distrbution abbnormally Detectet"
            abnormally.append((col,abnormally_indicator,shapiro_resualt))


    abnormally_df = pd.DataFrame(abnormally,columns=["Feature","abnormally_indicator","Abnormally Status"])  
    return abnormally_df

# %%
abnornmally_indicator(data_df)
# Out:
#    Feature  abnormally_indicator                 Abnormally Status
# 0     f_00          8.048047e-01              Normally Distirbuted
# 1     f_01          9.558341e-01              Normally Distirbuted
# 2     f_02          7.717363e-01              Normally Distirbuted
# 3     f_03          5.071116e-01              Normally Distirbuted
# 4     f_04          4.264995e-01              Normally Distirbuted
# 5     f_05          9.887279e-01              Normally Distirbuted
# 6     f_06          3.011470e-01              Normally Distirbuted
# 7     f_07          0.000000e+00  Distrbution abbnormally Detectet
# 8     f_08          0.000000e+00  Distrbution abbnormally Detectet
# 9     f_09          0.000000e+00  Distrbution abbnormally Detectet
# 10    f_10          0.000000e+00  Distrbution abbnormally Detectet
# 11    f_11          0.000000e+00  Distrbution abbnormally Detectet
# 12    f_12          0.000000e+00  Distrbution abbnormally Detectet
# 13    f_13          0.000000e+00  Distrbution abbnormally Detectet
# 14    f_14          5.629967e-01              Normally Distirbuted
# 15    f_15          7.478742e-01              Normally Distirbuted
# 16    f_16          6.558671e-01              Normally Distirbuted
# 17    f_17          9.625947e-01              Normally Distirbuted
# 18    f_18          7.957408e-01              Normally Distirbuted
# 19    f_19          9.133403e-01              Normally Distirbuted
# 20    f_20          1.050585e-01              Normally Distirbuted
# 21    f_21          4.309510e-01              Normally Distirbuted
# 22    f_22          5.754255e-16  Distrbution abbnormally Detectet
# 23    f_23          6.267771e-13  Distrbution abbnormally Detectet
# 24    f_24          9.434243e-08  Distrbution abbnormally Detectet
# 25    f_25          9.014025e-17  Distrbution abbnormally Detectet
# 26    f_26          4.429073e-36  Distrbution abbnormally Detectet
# 27    f_27          1.863585e-36  Distrbution abbnormally Detectet
# 28    f_28          2.838907e-20  Distrbution abbnormally Detectet

# %%
plt.figure(figsize=(30,16))
plt.suptitle("Categorical Columns Distribution")

for each,col in enumerate(categorial_columns, start=1):
    plt.subplot(3,3,each)
    sns.countplot(data=data_df,x=col,palette="Set2")
    plt.title(f'{col} count Distrbution')

# %%
def poisson_indicator(df):

    poisson = []
    for col in df.columns:
        if df.dtypes[col] in ['int8','int16','int32','int64','uint8']:
            # alpha level
            alpha = 0.05
            # Sample Size
            lenght = len(df[col])
            freedom = lenght -1

            col_mean = df[col].mean()
            dev = ((data_df[col]- col_mean)**2).sum() / col_mean

            q_lower = alpha / 2
            q_upper= (1- alpha) /2

            chi2_lower = chi2.ppf(q_lower, freedom)
            chi2_upper = chi2.ppf(q_upper, freedom)

            if (dev < chi2_lower) or (dev > chi2_upper):
                resualt = " Not Poisson Distributed "
                poisson.append((col,resualt))
            else:
                resualt = "Poisson Distributed"
                poisson.append((col,resualt))
        else:
            resualt = "Not Categorial Column"
            poisson.append((col, resualt))
    poisson_df = pd.DataFrame(poisson ,columns=["Feature","Poisson"])
    return poisson_df

# %%
poisson_indicator(data_df)
# Out:
#    Feature                    Poisson
# 0     f_00      Not Categorial Column
# 1     f_01      Not Categorial Column
# 2     f_02      Not Categorial Column
# 3     f_03      Not Categorial Column
# 4     f_04      Not Categorial Column
# 5     f_05      Not Categorial Column
# 6     f_06      Not Categorial Column
# 7     f_07   Not Poisson Distributed
# 8     f_08   Not Poisson Distributed
# 9     f_09   Not Poisson Distributed
# 10    f_10   Not Poisson Distributed
# 11    f_11   Not Poisson Distributed
# 12    f_12   Not Poisson Distributed
# 13    f_13   Not Poisson Distributed
# 14    f_14      Not Categorial Column
# 15    f_15      Not Categorial Column
# 16    f_16      Not Categorial Column
# 17    f_17      Not Categorial Column
# 18    f_18      Not Categorial Column
# 19    f_19      Not Categorial Column
# 20    f_20      Not Categorial Column
# 21    f_21      Not Categorial Column
# 22    f_22      Not Categorial Column
# 23    f_23      Not Categorial Column
# 24    f_24      Not Categorial Column
# 25    f_25      Not Categorial Column
# 26    f_26      Not Categorial Column
# 27    f_27      Not Categorial Column
# 28    f_28      Not Categorial Column

# %% [markdown]
# # _Preprocess_

# %%
# PowerTransformer
pt = PowerTransformer()
x = pt.fit_transform(data_df)
data_df = pd.DataFrame(x, columns=data_df.columns)
data_df.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0 -0.389230 -0.917652  0.647948  0.590717 -0.824836  0.734685  2.259470
# 1 -0.688368 -0.458647  0.653182  0.995359 -1.644030  0.864898 -0.085604
# 2  0.805709  0.319397 -1.166935 -0.622421  0.108371  0.785018  1.990489
# 3 -0.500469  0.223997  0.262677  0.234061  0.417047 -1.218768  0.144455
# 4 -0.670427 -1.044482 -0.270854 -1.833338 -0.285955 -1.849243  0.787627
#
#        f_07      f_08      f_09  ...      f_19      f_20      f_21      f_22  \
# 0 -0.977987  1.383372  1.039938  ... -0.472922 -0.753925 -0.763110 -0.707876
# 1 -0.977987 -0.875405 -0.179925  ... -0.423594 -0.088164 -1.777545 -0.535582
# 2  0.021718  1.017648 -0.394246  ... -0.408425 -1.598612  1.194423  2.203065
# 3  0.286548 -1.213526  0.917564  ...  0.620278  1.283827  0.532884  0.731623
# 4  0.756900  0.187543 -0.394246  ... -1.614933 -0.432406  0.321899  0.228337
#
#        f_23      f_24      f_25      f_26      f_27      f_28
# 0  0.911477 -0.678852  0.768543  0.960344  1.042536  0.694234
# 1  0.453824  1.031505 -0.117686 -0.550783  0.367242 -1.636652
# 2  0.086974 -1.519163 -0.568662  0.978900 -0.926277 -2.296373
# 3 -1.218086  0.826492 -1.173592 -0.395085 -0.100021  0.326682
# 4 -1.482684  0.847999 -0.613935  1.164389 -0.374203 -1.160058
#
# [5 rows x 29 columns]

# %% [markdown]
# # Feature Selection

# %%
# BayesianGaussianMixture
bgm = BayesianGaussianMixture(n_components=7,covariance_type='full',random_state=1,n_init=5,tol=0.01)

# Fit Model
preiction = bgm.fit_predict(x)
pp  = bgm.predict_proba(x)

# %%
plt.figure(figsize=(21,7))
for i in range(bgm.means_.shape[0]):
    plt.scatter(np.arange(x.shape[1]),bgm.means_[i])
plt.xticks(np.arange(x.shape[1]),labels=data_df.columns)
plt.show()

# %%
usefull_features = ['f_07', 'f_08','f_09','f_10','f_11','f_12','f_13','f_22','f_23','f_24','f_25','f_26','f_27','f_28']

# %% [markdown]
# # _Create Data Frame with porbility More than 80%_

# %%
prediction_df = pd.DataFrame(pp,columns=[f'prediction_probea_{i}' for i in range(7)])
prediction_df.head()
# Out:
#    prediction_probea_0  prediction_probea_1  prediction_probea_2  \
# 0             0.003510             0.000347             0.002491
# 1             0.000013             0.006764             0.051131
# 2             0.112169             0.000967             0.000010
# 3             0.078531             0.028807             0.011671
# 4             0.000008             0.982739             0.000002
#
#    prediction_probea_3  prediction_probea_4  prediction_probea_5  \
# 0             0.011334         5.379987e-07             0.977711
# 1             0.903429         1.905648e-02             0.000476
# 2             0.000148         4.141949e-09             0.886635
# 3             0.012068         8.688512e-01             0.000014
# 4             0.017082         7.101590e-07             0.000003
#
#    prediction_probea_6
# 0             0.004606
# 1             0.019130
# 2             0.000071
# 3             0.000057
# 4             0.000164

# %%
data_df[[f'prediction_probea_{i}' for i in range(7)]] =pp
data_df.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0 -0.389230 -0.917652  0.647948  0.590717 -0.824836  0.734685  2.259470
# 1 -0.688368 -0.458647  0.653182  0.995359 -1.644030  0.864898 -0.085604
# 2  0.805709  0.319397 -1.166935 -0.622421  0.108371  0.785018  1.990489
# 3 -0.500469  0.223997  0.262677  0.234061  0.417047 -1.218768  0.144455
# 4 -0.670427 -1.044482 -0.270854 -1.833338 -0.285955 -1.849243  0.787627
#
#        f_07      f_08      f_09  ...      f_26      f_27      f_28  \
# 0 -0.977987  1.383372  1.039938  ...  0.960344  1.042536  0.694234
# 1 -0.977987 -0.875405 -0.179925  ... -0.550783  0.367242 -1.636652
# 2  0.021718  1.017648 -0.394246  ...  0.978900 -0.926277 -2.296373
# 3  0.286548 -1.213526  0.917564  ... -0.395085 -0.100021  0.326682
# 4  0.756900  0.187543 -0.394246  ...  1.164389 -0.374203 -1.160058
#
#    prediction_probea_0  prediction_probea_1  prediction_probea_2  \
# 0             0.003510             0.000347             0.002491
# 1             0.000013             0.006764             0.051131
# 2             0.112169             0.000967             0.000010
# 3             0.078531             0.028807             0.011671
# 4             0.000008             0.982739             0.000002
#
#    prediction_probea_3  prediction_probea_4  prediction_probea_5  \
# 0             0.011334         5.379987e-07             0.977711
# 1             0.903429         1.905648e-02             0.000476
# 2             0.000148         4.141949e-09             0.886635
# 3             0.012068         8.688512e-01             0.000014
# 4             0.017082         7.101590e-07             0.000003
#
#    prediction_probea_6
# 0             0.004606
# 1             0.019130
# 2             0.000071
# 3             0.000057
# 4             0.000164
#
# [5 rows x 36 columns]

# %%
data_df["prerdiction_proba"] = np.max(pp,axis=1)
data_df.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0 -0.389230 -0.917652  0.647948  0.590717 -0.824836  0.734685  2.259470
# 1 -0.688368 -0.458647  0.653182  0.995359 -1.644030  0.864898 -0.085604
# 2  0.805709  0.319397 -1.166935 -0.622421  0.108371  0.785018  1.990489
# 3 -0.500469  0.223997  0.262677  0.234061  0.417047 -1.218768  0.144455
# 4 -0.670427 -1.044482 -0.270854 -1.833338 -0.285955 -1.849243  0.787627
#
#        f_07      f_08      f_09  ...      f_27      f_28  prediction_probea_0  \
# 0 -0.977987  1.383372  1.039938  ...  1.042536  0.694234             0.003510
# 1 -0.977987 -0.875405 -0.179925  ...  0.367242 -1.636652             0.000013
# 2  0.021718  1.017648 -0.394246  ... -0.926277 -2.296373             0.112169
# 3  0.286548 -1.213526  0.917564  ... -0.100021  0.326682             0.078531
# 4  0.756900  0.187543 -0.394246  ... -0.374203 -1.160058             0.000008
#
#    prediction_probea_1  prediction_probea_2  prediction_probea_3  \
# 0             0.000347             0.002491             0.011334
# 1             0.006764             0.051131             0.903429
# 2             0.000967             0.000010             0.000148
# 3             0.028807             0.011671             0.012068
# 4             0.982739             0.000002             0.017082
#
#    prediction_probea_4  prediction_probea_5  prediction_probea_6  \
# 0         5.379987e-07             0.977711             0.004606
# 1         1.905648e-02             0.000476             0.019130
# 2         4.141949e-09             0.886635             0.000071
# 3         8.688512e-01             0.000014             0.000057
# 4         7.101590e-07             0.000003             0.000164
#
#    prerdiction_proba
# 0           0.977711
# 1           0.903429
# 2           0.886635
# 3           0.868851
# 4           0.982739
#
# [5 rows x 37 columns]

# %%
data_df['predict'] = np.argmax(pp,axis=1)
data_df.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0 -0.389230 -0.917652  0.647948  0.590717 -0.824836  0.734685  2.259470
# 1 -0.688368 -0.458647  0.653182  0.995359 -1.644030  0.864898 -0.085604
# 2  0.805709  0.319397 -1.166935 -0.622421  0.108371  0.785018  1.990489
# 3 -0.500469  0.223997  0.262677  0.234061  0.417047 -1.218768  0.144455
# 4 -0.670427 -1.044482 -0.270854 -1.833338 -0.285955 -1.849243  0.787627
#
#        f_07      f_08      f_09  ...      f_28  prediction_probea_0  \
# 0 -0.977987  1.383372  1.039938  ...  0.694234             0.003510
# 1 -0.977987 -0.875405 -0.179925  ... -1.636652             0.000013
# 2  0.021718  1.017648 -0.394246  ... -2.296373             0.112169
# 3  0.286548 -1.213526  0.917564  ...  0.326682             0.078531
# 4  0.756900  0.187543 -0.394246  ... -1.160058             0.000008
#
#    prediction_probea_1  prediction_probea_2  prediction_probea_3  \
# 0             0.000347             0.002491             0.011334
# 1             0.006764             0.051131             0.903429
# 2             0.000967             0.000010             0.000148
# 3             0.028807             0.011671             0.012068
# 4             0.982739             0.000002             0.017082
#
#    prediction_probea_4  prediction_probea_5  prediction_probea_6  \
# 0         5.379987e-07             0.977711             0.004606
# 1         1.905648e-02             0.000476             0.019130
# 2         4.141949e-09             0.886635             0.000071
# 3         8.688512e-01             0.000014             0.000057
# 4         7.101590e-07             0.000003             0.000164
#
#    prerdiction_proba  predict
# 0           0.977711        5
# 1           0.903429        3
# 2           0.886635        5
# 3           0.868851        4
# 4           0.982739        1
#
# [5 rows x 38 columns]

# %%
# Create Train DataSet
train_index = np.array([])
for i in range(7):
    index = data_df[(data_df.predict == i) & (data_df.prerdiction_proba > 0.80)].index
    train_index = np.concatenate((train_index, index))

# %%
X = data_df.loc[train_index][usefull_features]
Y = data_df.loc[train_index]['predict']

# %%
X.head()
# Out:
#           f_07      f_08      f_09      f_10      f_11      f_12      f_13  \
# 13.0 -0.270117 -0.301642  0.788933 -0.320556  0.731665 -0.614590 -2.025880
# 18.0  0.530261 -1.213526  0.653205  0.884051 -0.961001  0.148356 -2.025880
# 25.0  1.541295  0.187543  0.917564  0.706932 -0.961001 -1.292560  0.086073
# 30.0 -0.270117  0.622133  1.039938 -0.320556  0.066905 -0.083596  0.317221
# 45.0  0.756900  1.203800  0.013988 -0.567775  0.066905 -1.737993 -0.162832
#
#           f_22      f_23      f_24      f_25      f_26      f_27      f_28
# 13.0  1.200330 -0.012989 -0.944818 -0.385018  0.039722  0.303931 -0.513935
# 18.0 -0.354208  0.480815 -1.108745 -1.027170 -0.664048  0.132524  0.080997
# 25.0 -1.506413  0.182714 -0.423969  0.084220  0.327505 -0.960513  0.486739
# 30.0 -0.766313  0.857243 -0.946473  0.558696  2.009452 -0.392322  1.111589
# 45.0 -1.058572  0.508469  2.206744 -0.513344  0.132409 -0.177854 -0.236899

# %%
Y.head()
# Out:
# 13.0    0
# 18.0    0
# 25.0    0
# 30.0    0
# 45.0    0
# Name: predict, dtype: int64

# %%
from sklearn.metrics import balanced_accuracy_score ,roc_auc_score

# %%
params_lgb = {'learning_rate': 0.07,'objective': 'multiclass','boosting': 'gbdt','verbosity': -1,'n_jobs': -1, 'num_classes':7}

# %%
lgbm_prediction_proba = 0
classifier_score = []

gkf = StratifiedKFold(10,shuffle=True,random_state=1)
for fold,(trn,val) in enumerate(gkf.split(X,Y)):
    X_train = lgb.Dataset(X.iloc[trn],Y.iloc[trn],feature_name=usefull_features)
    X_val = lgb.Dataset(X.iloc[val],Y.iloc[val],feature_name=usefull_features)
    
    lgb_model = lgb.train(params=params_lgb, train_set=X_train,valid_sets=X_val,num_boost_round=5000,callbacks=[lgb.early_stopping(stopping_rounds=100,verbose=True),])
    Y_prediction_proba = lgb_model.predict(X.iloc[val])
    Y_predict = np.argmax(Y_prediction_proba, axis=1)
    
    S = (balanced_accuracy_score(Y.iloc[val],Y_predict),roc_auc_score(Y.iloc[val],Y_prediction_proba,average="weighted",multi_class="ovo"))
    classifier_score.append(S)
    lgbm_prediction_proba =+ lgb_model.predict(data_df[usefull_features]) / 10
pd.DataFrame(classifier_score,columns=["Balanced Accuracy Score","roc accuracy score"]).mean(0)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [580]	valid_0's multi_logloss: 0.0154186
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [792]	valid_0's multi_logloss: 0.0147975
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [596]	valid_0's multi_logloss: 0.0139079
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [407]	valid_0's multi_logloss: 0.0192374
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [536]	valid_0's multi_logloss: 0.0176625
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [590]	valid_0's multi_logloss: 0.0158156
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [646]	valid_0's multi_logloss: 0.0117935
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [458]	valid_0's multi_logloss: 0.0162144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [634]	valid_0's multi_logloss: 0.0130694
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [630]	valid_0's multi_logloss: 0.0117628
# Balanced Accuracy Score    0.994533
# roc accuracy score         0.999972
# dtype: float64

# %%
ss = pd.read_csv('../input/tabular-playground-series-jul-2022/sample_submission.csv')

# %%
ss.Predicted = np.argmax(lgbm_prediction_proba,axis=1)
ss.to_csv("submission.csv",index=False)
